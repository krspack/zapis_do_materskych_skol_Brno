# %% [markdown]
# ## Rozřazení
#
# Algoritmus funkce match() prochází seznam uchazečů a každého přiřadí do školky jeho první volby, pokud má tato školka ještě kapacitu. Toto přiřazení ale není finální, protože dříve nebo později přijde řada na dítě, jehož nejoblíbenější školka už je plná. V tomto okamžiku dojde na porovnávání počtu bodů. Pokud má dítě více bodů než poslední uchazeč "nad čarou", do školky se dostane, ale onen poslední z ní vypadává. Vyřazeného uchazeče se algoritmus následně pokusí stejným způsobem spárovat se školkou jeho druhé volby a tak stále dokola. Tímto způsobem algoritmus přepisuje seznamy dětí pro každou školku, dokud se nedostane do stabilního stavu, kdy nikdo nemůže vyřadit nikoho. Tento stav vrátí jako výsledek.

# %%
import csv
import pandas as pd
import random
import copy
import numpy as np
import datetime
from dateutil.relativedelta import relativedelta
import sys
from matching.games import HospitalResident
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)

oznaceni_testu = 'novy'

deti = pd.read_csv("{}_test/deti_test.csv".format(oznaceni_testu), dtype = {
    'dite_id': 'string', 
    'spadova_skolka': 'string', 
    'skolka_sourozence': 'string'})
skolky = pd.read_csv("{}_test/skolky_test.csv".format(oznaceni_testu), dtype = {
    'skolka_id': 'string'})

prihlasky = pd.read_csv("{}_test/prihlasky.csv".format(oznaceni_testu), dtype = {
   'dite': 'string',
   'skolka': 'string'})

body = pd.read_csv("{}_test/body.csv".format(oznaceni_testu), dtype = {
    'dite_id': 'string', 
    'spadova_skolka': 'string', 
    'skolka_sourozence': 'string'})


# vstup pro funkci "match" c. 1: priority uchazecu
def get_priorities(tabulka_prihlasek):
    # Funkce vytvoří slovník uchazečů a jejich prioritních seznamů školek.
    prihlasky_groupedby_kids = tabulka_prihlasek.groupby('dite')['skolka'].agg(list)
    return prihlasky_groupedby_kids.to_dict()        
priority = get_priorities(prihlasky)

"""
def get_priorities_names(priority_dict):
    priorities_names = {}
    for k, v in priority_dict.items():
        k = deti.loc[deti['dite_id'] == int(k), 'jmeno'].item()  + ' (' + k + ')'
        v = [(skolky.loc[skolky['skolka_id'] == int(i), 'nazev_kratky'].item()) + ' (' + i + ')' for i in v]
        priorities_names[k] = v
    return priorities_names
priority_jmena = get_priorities_names(priority)


print("Uchazeči a jejich vybrané školky v pořadí podle oblíbenosti:")
print()
for a, b in priority_jmena.items():
    print(a, b)
"""

# vstup pro funkci "match" c. 2: kapacity skolek
def get_volna_mista(df_skolky):
    # vyrobí slovník "školka: kapacita"
    volna_mista = df_skolky[['skolka_id', 'volna_mista']]
    volna_mista = skolky.set_index('skolka_id')['volna_mista'].to_dict()
    volna_mista = {str(k):v for k, v in volna_mista.items()}
    return volna_mista
volna_mista = get_volna_mista(skolky)

# vstup pro funkci "match" c. 3: priority skolek, vyjadrene poradim obodovanych uchazecu o kazdou skolku
def get_schools_longlists(body_df, prihlasky_df): 
    # Z tabulky body_df vybere jen relevantni udaje podle toho, kdo se kam hlásí.
    # výstup je slovnik typu "skolka a k ni vsechny deti, co se na ni hlasi, seřazené podle počtu bodů"
    prihlasky_groupedby_schools = prihlasky_df.groupby('skolka')['dite'].agg(list)
    prihlasky_groupedby_schools = prihlasky_groupedby_schools.to_dict()
    longlists = {}
    schools = prihlasky_groupedby_schools.keys()
    for s in schools:
        all_kids_one_school = body_df[['dite_id', str(s)]].copy()  
        all_kids_one_school['dite_id'] = all_kids_one_school['dite_id'].astype(str)
        kids_applyint_to_one_school = all_kids_one_school.loc[all_kids_one_school['dite_id'].isin(prihlasky_groupedby_schools[str(s)])].copy()
        kids_applyint_to_one_school.sort_values(by=str(s), ascending=False, inplace=True)
        kids_applyint_to_one_school.reset_index(inplace=True, drop=True)
        sorted_longlist = tuple(kids_applyint_to_one_school['dite_id'])
        longlists[str(s)] = [str(x) for x in sorted_longlist]
    return longlists

serazeni_uchazeci = get_schools_longlists(body, prihlasky)

"""
def get_longlists_names(longlists_dict):
    longlists_names = {}
    for k, v in longlists_dict.items():
        k = skolky.loc[skolky['skolka_id'] == int(k),'nazev_kratky'].item()
        v = [(deti.loc[deti['dite_id'] == int(i), 'jmeno'].item()) for i in v]
        longlists_names[k] = v
    return longlists_names
serazeni_uchazeci_jmena = get_longlists_names(serazeni_uchazeci)
print()
for k,v in serazeni_uchazeci_jmena.items():
    print(k,v)
    print()
"""

"""
print('priority uchazečů: ', priority)
print('uchazeči o každou školu, seřazení podle bodů: ', serazeni_uchazeci)
print('školky a jejich kapacity: ', volna_mista)
"""

# ------------------------------------------------------------------------------------

def match(priority_zaku, priority_skolek, kapacity_skolek):
    game = HospitalResident.create_from_dictionaries(priority_zaku, priority_skolek, kapacity_skolek)
    schools_shortlists = game.solve(optimal="resident")
    return schools_shortlists
rozrazeni = match(priority, serazeni_uchazeci, volna_mista)

def save_results(results, folder):
    with open('{}_test/vysledek.csv'.format(folder), 'w') as file:
        writer = csv.DictWriter(file, fieldnames = ['dite', 'skolka', 'poradi'])
        writer.writeheader()
        for school, shortlist in results.items():
            for index, person in enumerate(shortlist):
                d = {'skolka': school, 'poradi': index + 1, 'dite': person}
                writer.writerow(d)
    return
save_results(rozrazeni, oznaceni_testu)

def get_vysledek_se_jmeny(vysledek, deti_df):
    names = {}
    for k, v in vysledek.items():
        k_nazev = skolky.loc[skolky['skolka_id'] == k.name,'nazev_kratky'].item() 
        v_jmeno = [(deti_df.loc[deti_df['dite_id'] == i.name, 'jmeno'].item() + ' (' + i.name + ')') for i in v]
        names[k_nazev + ' (' + k.name + ')'] = v_jmeno
    return names
vysledek_se_jmeny = get_vysledek_se_jmeny(rozrazeni, deti)
print('Výsledky - kdo se dostal kam: ')
print()
for k,v in vysledek_se_jmeny.items():
    print(k,v)
    print()

def kdo_se_nedostal(vysledek, deti_df):
    uspesni_uchazeci = []
    for v in vysledek.values():
        uspesni_uchazeci += v
    uspesni_uchazeci = [_.name for _ in uspesni_uchazeci]
    
    neuspesni = {}
    for _ in deti_df['dite_id']:
        if _ not in uspesni_uchazeci:
            neuspesni[_] = deti_df.loc[deti_df['dite_id'] == _, 'jmeno'].item()
    return neuspesni
print()
print()
print('Neúspěšní uchazeči:')
print()
for k, v in kdo_se_nedostal(rozrazeni, deti).items():
    print (v + ' (' + str(k) + ')')
# Out:
# Výsledky - kdo se dostal kam:
#
# MŠ Absolonova (0) ['Ivana Test Pechová (2823)', 'Gabriela Test Tomášková (4335)', 'Kamil Test Němec (2159)', 'Anton Test Švadlenka (1294)', 'Miroslav Test Mrázek (1448)', 'Stanislava Test Svobodová (4501)', 'Irena Test Malá (4361)', 'Nela Test Martínková (4942)']
#
# MŠ Amerlingova (1) ['Soňa Test Stará (3791)', 'Kateřina Test Pechová (2973)', 'Tomáš Test Polák (133)', 'Dominika Test Málková (4243)', 'Eliška Test Kadlecová (4267)', 'Zdeňka Test Křenková (3933)', 'Miloslava Test Nováková (4700)', 'Milan Test Dvořák (1053)']
#
# MŠ Bořetická (10) ['Karolína Test Pechová (2923)', 'Pavel Test Konečný (327)', 'Robin Test Král (2266)', 'Juraj Test Soukup (1663)', 'Irena Test Havlíčková (4386)', 'Petr Test Vávra (74)', 'Eliška Test Marečková (4279)', 'Samuel Test Urban (1962)']
#
# MŠ Skořepka (100) ['Stanislava Test Horáková (4508)', 'Hana Test Kopecká (2732)', 'Simona Test Hajná (3747)', 'Jakub Test Kadlec (580)', 'Štěpánka Test Vondráčková (4977)', 'Zuzana Test Smetanová (3990)', 'Richard Test Kratochvíl (1479)', 'Eliška Test Smetanová (4290)']
#
# MŠ Slavíčkova (101) ['Denisa Test Havlíčková (2636)', 'Radim Test Dvořák (753)', 'David Test Málek (443)', 'Miroslav Test Polák (1433)', 'Anton Test Novotný (1252)', 'Daniela Test Rýdlová (4180)', 'Petra Test Vlčková (3634)', 'Vladimír Test Procházka (1555)']
#
# MŠ Slunná (102) ['Tomáš Test Mach (123)', 'Lukáš Test Němec (359)', 'Viola Test Šimková (4824)', 'Dominika Test Velínská (4245)', 'Tereza Test Urbanová (3821)', 'Karel Test Šimek (2420)', 'Vladimír Test Beneš (2118)', 'Viktor Test Novotný (1752)']
#
# MŠ Soukenická (103) ['Ivan Test Švadlenka (1244)', 'Miroslav Test Pospíšil (1410)', 'Marta Test Pospíšilová (3262)', 'Stanislav Test Toman (2026)', 'Daniela Test Velínská (4195)', 'Pavel Test Navrátil (337)', 'Anton Test Novák (1250)', 'Dominika Test Kočová (4238)']
#
# MŠ Staňkova (104) ['Stanislav Test Šimek (2020)', 'Tereza Test Kučerová (3806)', 'Ondřej Test Staněk (638)', 'Simona Test Stará (3741)', 'Denisa Test Pechová (2623)', 'Jakub Test Janda (584)', 'Stanislava Test Tichá (4518)', 'Samuel Test Růžička (1967)']
#
# MŠ Sluníčko, Strnadova (105) ['Aleš Test Novotný (1002)', 'Barbora Test Pechová (2573)', 'Vladimíra Test Málková (4643)', 'Jan Test Novotný (2)', 'Marek Test Smetana (490)', 'Kamila Test Malá (4411)', 'Tomáš Test Bílý (719)', 'Milan Test Horváth (1082)']
#
# MŠ Synkova (106) ['Květoslava Test Konečná (4666)', 'Eliška Test Králová (4276)', 'Petra Test Černá (3604)', 'Karel Test Kovařík (2406)', 'Tereza Test Vondráčková (3827)', 'Ján Test Pospíšil (1110)', 'Petr Test Kovařík (56)', 'Helena Test Nováková (2750)']
#
# MŠ Šaumannova (107) ['Jan Test Navrátil (37)', 'Ludmila Test Urbanová (3171)', 'Tomáš Test Málek (143)', 'Pavel Test Janda (334)', 'Samuel Test Weiss (1999)', 'Renata Test Pospíšilová (3662)', 'Natálie Test Benešová (3431)', 'Jana Test Konečná (2866)']
#
# MŠ Škrétova (108) ['Helena Test Vondráčková (2777)', 'Helena Test Smetanová (2790)', 'Jakub Test Král (566)', 'Tereza Test Švadlenková (3844)', 'Zuzana Test Martínková (3992)', 'Jan Test Černý (4)', 'Nikola Test Tomášková (3485)', 'Viola Test Tomášková (4835)']
#
# MŠ Šrámkova (109) ['Miloslava Test Šimková (4724)', 'Kamila Test Procházková (4405)', 'Tomáš Test Mach (723)', 'Nela Test Tesařová (4937)', 'Jaroslav Test Staněk (838)', 'Marek Test Beneš (468)', 'Vladislav Test Novák (2050)', 'Ondřej Test Dušek (635)']
#
# MŠ Bosonožská (11) ['Eva Test Martínková (2692)', 'Marta Test Vondráčková (3277)', 'Petra Test Křenková (3633)', 'Radek Test Kratochvíl (929)', 'Ján Test Svatoš (1121)', 'Milan Test Soukup (1063)', 'Anton Test Martínek (1292)', 'Štěpánka Test Stará (4991)']
#
# MŠ Šromova (110) ['Jaroslav Test Beneš (818)', 'Jan Test Pospíšil (10)', 'Peter Test Hájek (1314)', 'Jan Test Dušek (35)', 'Michaela Test Rýdlová (3330)', 'Klára Test Nováková (3000)', 'Miroslav Test Fiala (1415)', 'Jindřich Test Toman (2326)']
#
# MŠ Štolcova 21 (111) ['Róbert Test Švadlenka (1844)', 'Jana Test Šimková (2874)', 'Lenka Test Velínská (3095)', 'Marcela Test Křenková (3233)', 'Radek Test Fiala (915)', 'Irena Test Králová (4376)', 'Michaela Test Šimková (3324)', 'Erik Test Hájek (1864)']
#
# MŠ Štolcova 51 (112) ['Hana Test Šimková (2724)', 'Adam Test Marek (511)', 'Josef Test Mareček (2395)', 'Samuel Test Staněk (1988)', 'Ivan Test Horváth (1232)', 'Lenka Test Marečková (3079)', 'Erik Test Tomáš (1875)', 'Jozef Test Němec (1159)']
#
# MŠ Sluníčko, Štouračova (113) ['Lukáš Test Švadlenka (394)', 'Jana Test Benešová (2881)', 'Gabriela Test Konečná (4316)', 'Anton Test Mach (1273)', 'Štěpánka Test Kočová (4988)', 'Igor Test Toman (1526)', 'Nela Test Smetanová (4940)', 'Milan Test Svatoš (1071)']
#
# MŠ Švermova (114) ['Blanka Test Pechová (4123)', 'Marta Test Dvořáková (3253)']
#
# MŠ Tišnovská (115) ['Lenka Test Křížová (4460)', 'Robin Test Staněk (2288)', 'Barbora Test Procházková (2555)', 'Miloslava Test Kučerová (4706)', 'Helena Test Rýdlová (2780)']
#
# MŠ Trnkova (116) []
#
# MŠ Tučkova (117) ['Natálie Test Křížová (3410)', 'Milada Test Křenková (4783)']
#
# MŠ Paraplíčko (118) ['Adam Test Macháček (536)']
#
# MŠ U Lípy Svobody (119) []
#
# MŠ Bosonožské nám. (12) ['Milada Test Kadlecová (4767)', 'Marta Test Velínská (3295)', 'Monika Test Pechová (3373)', 'Barbora Test Hájková (2572)', 'Tereza Test Šťastná (3839)', 'Erik Test Janda (1884)', 'Ján Test Novotný (1102)', 'Gabriela Test Zábranská (4328)']
#
# MŠ Adélka (120) ['Kamil Test Fiala (2165)']
#
# MŠ Údolní (121) []
#
# MŠ Pod Špilberkem (122) ['Samuel Test Martínek (1992)']
#
# MŠ Kosmonautů (123) ['Matúš Test Němec (1909)', 'Pavlína Test Pechová (3573)']
#
# MŠ Úvoz (124) []
#
# MŠ Uzbecká (125) []
#
# MŠ V Aleji (126) []
#
# MŠ Vackova (127) ['Pavlína Test Ronovská (3596)', 'Robin Test Navrátil (2287)', 'Jana Test Marešová (2863)']
#
# MŠ Vedlejší (128) ['Alena Test Veselá (4007)', 'Štěpán Test Svatoš (2471)', 'David Test Tomáš (425)', 'Viktor Test Veselý (1757)', 'Stanislav Test Urban (2012)', 'Anna Test Havlíčková (2536)', 'Monika Test Nováková (3350)', 'Stanislav Test Weiss (2049)']
#
# MŠ Velkopavlovická (129) ['Josef Test Hájek (2364)', 'Stanislava Test Kopecká (4532)', 'Marcela Test Černá (3204)', 'Lenka Test Nováková (4450)', 'Aleš Test Svoboda (1001)', 'Natálie Test Kopecká (3432)', 'Soňa Test Tomášková (3785)', 'David Test Starý (441)']
#
# MŠ Božetěchova (13) ['Květoslava Test Marešová (4663)', 'Anton Test Černý (1254)', 'Štěpánka Test Pospíšilová (4962)', 'Lucia Test Mrázková (3148)', 'Pavel Test Weiss (349)', 'Pavlína Test Kopecká (3582)', 'Zdeňka Test Jelínková (3920)', 'Renata Test Urbanová (3671)']
#
# MŠ Veslařská (130) ['Nikola Test Havlíčková (3486)', 'Igor Test Svatoš (1521)', 'Juraj Test Mareček (1695)', 'Miloslava Test Vlčková (4734)', 'Blanka Test Tichá (4118)', 'Štěpán Test Starý (2491)', 'Ludmila Test Šimková (3174)', 'Andrea Test Benešová (4081)']
#
# MŠ Vídeňská (131) ['Erik Test Švadlenka (1894)', 'Gabriela Test Urbanová (4321)', 'Marta Test Růžičková (3264)', 'Richard Test Bílý (1469)', 'Vladimíra Test Tomášková (4635)', 'Tomáš Test Starý (741)', 'Štefan Test Mach (1623)', 'Soňa Test Veselá (3757)']
#
# MŠ Vinařská (132) ['Marcela Test Mrázková (3248)', 'Petr Test Dušek (85)', 'Marek Test Hájek (464)', 'Helena Test Pechová (2773)', 'Marta Test Rýdlová (3280)', 'Štěpán Test Bílý (2469)', 'Ivana Test Dvořáková (2803)', 'Barbora Test Ronovská (2596)']
#
# MŠ Všetičkova (133) ['Alena Test Horáková (4008)', 'Vladislav Test Dušek (2085)', 'Vladimír Test Král (1566)', 'Marcela Test Hajná (3247)', 'Miloslava Test Málková (4743)', 'David Test Dvořák (403)', 'Patricia Test Pospíšilová (3512)', 'Lenka Test Vondráčková (3077)']
#
# MŠ Záhumenice (134) ['Veronika Test Bílá (3865)', 'Patrik Test Soukup (1713)', 'Ivana Test Hajná (2847)', 'Radek Test Janda (934)', 'Tomáš Test Němec (109)', 'Miloslav Test Novotný (2202)', 'Adam Test Novotný (502)', 'Tomáš Test Ronovský (746)']
#
# MŠ Zelná (135) ['Robin Test Mareš (2272)', 'Jiří Test Novotný (152)', 'Tomáš Test Beneš (718)', 'Milada Test Němcová (4759)', 'Aleš Test Němec (1009)', 'Samuel Test Tomáš (1975)', 'Petra Test Šimková (3624)', 'Stanislava Test Matějová (4519)']
#
# Masarykova MŠ (136) ['Dominika Test Stará (4241)', 'Josef Test Janda (2384)', 'Pavel Test Černý (304)', 'Lucia Test Bílá (3115)', 'Lukáš Test Bílý (369)', 'Adam Test Mach (523)', 'Tomáš Test Navrátil (737)', 'Pavel Test Vávra (324)']
#
# MŠ Sedmikráska (137) ['Vladimír Test Konečný (1577)', 'Richard Test Tomáš (1475)', 'Klára Test Svobodová (3001)', 'Alena Test Stará (4041)', 'Tomáš Test Macháček (136)', 'Marcela Test Marečková (3229)', 'Natálie Test Marešová (3413)', 'Martin Test Veselý (207)']
#
# MŠ Žižkova (138) ['Tomáš Test Novotný (702)', 'Viktor Test Svoboda (1751)', 'Veronika Test Pechová (3873)', 'Karolína Test Šťastná (2939)', 'Simona Test Konečná (3716)', 'Jakub Test Navrátil (587)', 'Veronika Test Procházková (3855)', 'Gabriela Test Pechová (4323)']
#
# MŠ Pohádka, Bratří Pelíšků (14) ['Vladimíra Test Hájková (4622)', 'Jana Test Kadlecová (2867)', 'Andrej Test Bílý (1369)', 'Viola Test Svobodová (4801)', 'Marcela Test Martínková (3242)', 'David Test Svatoš (421)', 'Zuzana Test Novotná (3952)', 'Patricia Test Nováková (3500)']
#
# MŠ Brechtova (15) ['Andrea Test Novotná (4052)', 'Miloslava Test Vondráčková (4727)', 'Patrik Test Dvořák (1703)', 'Hana Test Rýdlová (2730)', 'Anna Test Černá (2504)', 'Anna Test Benešová (2531)', 'Kamila Test Málková (4443)', 'Viktor Test Polák (1783)']
#
# MŠ Bulharská (16) ['Juraj Test Starý (1691)', 'Patrik Test Pospíšil (1710)', 'Eliška Test Černá (4254)', 'Pavlína Test Nováková (3550)', 'Štěpán Test Švadlenka (2494)', 'Petr Test Málek (93)', 'Tereza Test Procházková (3805)', 'Matúš Test Novák (1900)']
#
# MŠ Cihelní 1a (17) ['Štefan Test Martínek (1642)', 'Andrej Test Procházka (1355)', 'Alena Test Weissová (4049)', 'Nela Test Stará (4941)', 'Ivan Test Svoboda (1201)', 'Tomáš Test Svatoš (721)', 'Ondřej Test Veselý (607)', 'Štěpánka Test Křížová (4960)']
#
# MŠ Černopolní (18) ['Lenka Test Králová (3076)', 'Monika Test Tomášková (3385)', 'Aleš Test Hájek (1014)', 'Jiří Test Šimek (170)', 'Štěpánka Test Málková (4993)', 'Samuel Test Horák (1958)', 'Josef Test Ronovský (2396)', 'Marta Test Němcová (3259)']
#
# MŠ Kamarád, Čtvrtě (19) ['Alena Test Kadlecová (4017)', 'Zdeňka Test Novotná (3902)', 'Jaroslav Test Tomáš (825)', 'Martin Test Horváth (232)', 'Vladislava Test Švadlenková (4594)', 'Jindřich Test Marek (2311)', 'Irena Test Hlaváčková (4375)', 'Monika Test Weissová (3399)']
#
# MŠ Antonínská (2) ['Jindřich Test Kadlec (2330)', 'Miloslava Test Urbanová (4721)', 'Kamila Test Veselá (4407)', 'Pavlína Test Hlaváčková (3575)', 'Viktor Test Konečný (1777)', 'Jiří Test Mach (173)', 'Erik Test Hajný (1897)', 'Simona Test Weissová (3749)']
#
# MŠ Dobrovského (20) ['Andrej Test Weiss (1399)', 'Lenka Test Kadlecová (3067)', 'Lenka Test Pechová (3073)', 'Vladislava Test Konečná (4566)', 'Eva Test Kučerová (2656)', 'Kamila Test Urbanová (4421)', 'Igor Test Novotný (1502)', 'Vladimír Test Novotný (1552)']
#
# MŠ Žabka (21) ['Vladislav Test Veselý (2057)', 'Pavlína Test Weissová (3599)', 'Marcela Test Kopecká (3232)', 'Lenka Test Křížová (3060)', 'Aleš Test Soukup (1013)', 'Jana Test Černá (2854)', 'Stanislava Test Marešová (4513)', 'Denisa Test Konečná (2616)']
#
# MŠ Oříšek (22) ['Lenka Test Urbanová (3071)', 'Jozef Test Fiala (1165)', 'Natálie Test Králová (3426)', 'Anton Test Weiss (1299)', 'Eliška Test Veselá (4257)', 'Miloslav Test Šimek (2220)', 'Igor Test Janda (1534)', 'Štěpán Test Mrázek (2498)']
#
# MŠ Dubová (23) ['Andrej Test Šimek (1370)', 'Milada Test Stará (4791)', 'Daniela Test Novotná (4152)', 'Zuzana Test Bílá (3965)', 'Jindřich Test Procházka (2305)', 'Martin Test Švadlenka (244)', 'Miloslava Test Pechová (4723)', 'Radim Test Švadlenka (794)']
#
# MŠ Elišky Přemyslovny (24) ['Anton Test Dušek (1285)', 'Lenka Test Benešová (3081)', 'David Test Janda (434)', 'Patrik Test Mrázek (1748)', 'Renata Test Jelínková (3670)', 'Jana Test Stará (2891)', 'Kamila Test Stará (4441)', 'Hana Test Stará (2741)']
#
# MŠ Elišky Krásnohorské (25) ['Štefan Test Dvořák (1603)', 'Tereza Test Velínská (3845)', 'Juraj Test Horák (1658)', 'Helena Test Bílá (2765)', 'Daniela Test Svobodová (4151)', 'Klára Test Novotná (3002)', 'Juraj Test Novotný (1652)', 'Adam Test Dvořák (503)']
#
# MŠ Fanderlíkova (26) ['Vladimír Test Navrátil (1587)', 'Eva Test Vlčková (2684)', 'Miroslav Test Vlček (1428)', 'Lenka Test Nováková (3050)', 'Ivan Test Toman (1226)', 'Karel Test Toman (2426)', 'Róbert Test Bílý (1819)', 'Jana Test Malá (2861)']
#
# MŠ Francouzská (27) ['Ludmila Test Ronovská (3196)', 'Adam Test Hájek (514)', 'Natálie Test Svobodová (3401)', 'Vladislava Test Tichá (4568)', 'Lenka Test Smetanová (4490)', 'Lucia Test Malá (3111)', 'Alena Test Černá (4004)', 'Daniela Test Martínková (4192)']
#
# MŠ Gabriely Preissové (28) ['Blanka Test Hajná (4147)', 'Igor Test Urban (1512)', 'Denisa Test Nováková (2600)', 'Petra Test Velínská (3645)', 'Klára Test Pospíšilová (3012)', 'Simona Test Martínková (3742)', 'Marek Test Kříž (481)', 'Filip Test Málek (993)']
#
# MŠ Hatě (29) ['Kamila Test Marečková (4429)', 'Renata Test Šťastná (3689)', 'Adam Test Konečný (527)', 'Karel Test Hajný (2447)', 'Viktor Test Švadlenka (1794)', 'Eva Test Bílá (2665)', 'Blanka Test Konečná (4116)', 'Klára Test Křenková (3033)']
#
# MŠ Bellova (3) ['Josef Test Vlček (2378)', 'Juraj Test Staněk (1688)', 'Blanka Test Malá (4111)', 'Michal Test Novotný (252)', 'Miroslav Test Konečný (1427)', 'Aleš Test Urban (1012)', 'Dominika Test Šimková (4224)', 'Vladislav Test Marek (2061)']
#
# MŠ Rozárka (30) ['Peter Test Pekař (1339)', 'Simona Test Horáková (3708)', 'Zdeňka Test Vondráčková (3927)', 'Martin Test Procházka (205)', 'Pavel Test Tomáš (325)', 'Petra Test Marešová (3613)', 'Alena Test Martínková (4042)', 'Peter Test Mareček (1345)']
#
# MŠ Herčíkova 21 (31) ['Jakub Test Novák (550)', 'Radek Test Ronovský (946)', 'Kamila Test Hájková (4422)', 'Michaela Test Havlíčková (3336)', 'Aleš Test Vávra (1024)', 'Lenka Test Horáková (3058)', 'Marek Test Fiala (465)', 'Simona Test Matějová (3719)']
#
# MŠ Hněvkovského (32) ['Václav Test Janda (684)', 'Renata Test Benešová (3681)', 'Kamila Test Svobodová (4401)', 'Stanislava Test Stará (4541)', 'Eliška Test Růžičková (4264)', 'Jozef Test Navrátil (1187)', 'Václav Test Novotný (652)', 'Ján Test Mareš (1122)']
#
# MŠ Hochmanova (33) ['Hana Test Matějová (2719)', 'Simona Test Svobodová (3701)', 'Filip Test Marek (961)', 'Andrea Test Havlíčková (4086)', 'Miloslava Test Veselá (4707)', 'Vladimír Test Mrázek (1598)', 'Ivana Test Rýdlová (2830)', 'Kamil Test Růžička (2167)']
#
# MŠ Holásecká (34) ['Michal Test Mach (273)', 'Klára Test Králová (3026)', 'Andrej Test Staněk (1388)', 'Josef Test Svatoš (871)', 'Dominika Test Havlíčková (4236)', 'Josef Test Kříž (2381)', 'Pavlína Test Marečková (3579)', 'Robin Test Hájek (2264)']
#
# MŠ Horní (35) ['Eva Test Jelínková (2670)', 'Miloslav Test Hajný (2247)', 'Marie Test Martínková (4892)', 'Martin Test Mareš (222)', 'Alena Test Ronovská (4046)', 'Štěpánka Test Novotná (4952)', 'Anton Test Fiala (1265)', 'Karel Test Svoboda (2401)']
#
# MŠ Na kopečku u zvonečku (36) ['Blanka Test Veselá (4107)', 'Josef Test Veselý (2357)', 'Jakub Test Smetana (590)', 'Igor Test Málek (1543)', 'Radim Test Mareš (772)', 'Gabriela Test Černá (4304)', 'Helena Test Kučerová (2756)', 'Natálie Test Křenková (3433)']
#
# MŠ Horníkova (37) ['Josef Test Tomáš (2375)', 'Andrea Test Svobodová (4051)', 'Eva Test Kopecká (2682)', 'Pavlína Test Tesařová (3587)', 'Ivana Test Bílá (2815)', 'Anna Test Marečková (2529)', 'Hana Test Martínková (2742)', 'Kateřina Test Hajná (2997)']
#
# MŠ Hudcova (38) ['Eva Test Černá (2654)', 'Miloslav Test Ronovský (2246)', 'Jindřich Test Svoboda (2301)', 'Renata Test Malá (3661)', 'Michaela Test Velínská (3345)', 'Robin Test Fiala (2265)', 'Jiří Test Růžička (167)', 'Milan Test Navrátil (1087)']
#
# MŠ Husova (39) ['Ondřej Test Tomáš (625)', 'Monika Test Mrázková (3398)', 'Milada Test Vlčková (4784)', 'Jozef Test Novotný (1152)', 'Radim Test Hájek (764)', 'Vladimír Test Růžička (1567)', 'Zdeňka Test Zábranská (3928)', 'Nikola Test Vlčková (3484)']
#
# MŠ Pohádka, Běloruská (4) ['Marcela Test Veselá (3207)', 'Juraj Test Navrátil (1687)', 'Kamila Test Martínková (4442)', 'Vladimír Test Polák (1583)', 'Tomáš Test Smetana (740)', 'Štěpánka Test Rýdlová (4980)', 'Jakub Test Polák (583)', 'Marek Test Polák (483)']
#
# MŠ Chalabalova (40) ['Kamila Test Bílá (4415)', 'Lenka Test Růžičková (3064)', 'Milan Test Fiala (1065)', 'Václav Test Bílý (669)', 'Lucia Test Konečná (3116)', 'Helena Test Tomášková (2785)', 'Květoslava Test Dvořáková (4653)', 'Erik Test Staněk (1888)']
#
# MŠ Chodská (41) ['Eva Test Havlíčková (2686)', 'Zuzana Test Vondráčková (3977)', 'Karolína Test Černá (2904)', 'Dominika Test Marešová (4213)', 'Nela Test Jelínková (4920)', 'Radek Test Pekař (939)', 'Vladislava Test Martínková (4592)', 'Igor Test Pospíšil (1510)']
#
# MŠ Chodská (42) ['Veronika Test Hlaváčková (3875)', 'Ludmila Test Martínková (3192)', 'Viola Test Mrázková (4848)', 'Nela Test Havlíčková (4936)', 'Erik Test Kříž (1881)', 'Milan Test Hajný (1097)', 'Kamil Test Bílý (2169)', 'Květoslava Test Tichá (4668)']
#
# MŠ Pastelky, Jamborova (43) ['Klára Test Hajná (3047)', 'Erik Test Kadlec (1880)', 'Vladislav Test Toman (2076)', 'Štefan Test Mareš (1622)', 'Radim Test Kadlec (780)', 'Róbert Test Šimek (1820)', 'Aleš Test Mareš (1022)', 'Kateřina Test Havlíčková (2986)']
#
# MŠ Jana Broskvy (44) ['Zdeňka Test Smetanová (3940)', 'Andrea Test Nováková (4050)', 'Dominika Test Pechová (4223)', 'Michal Test Kříž (281)', 'Daniela Test Marešová (4163)', 'Hana Test Benešová (2731)', 'Alena Test Hajná (4047)', 'Radim Test Fiala (765)']
#
# MŠ Jihomoravské nám. 5 (45) ['Renata Test Velínská (3695)', 'Stanislava Test Malá (4511)', 'Natálie Test Dvořáková (3403)', 'Viola Test Velínská (4845)', 'Adam Test Kříž (531)', 'Štěpán Test Kratochvíl (2479)', 'Juraj Test Vlček (1678)', 'Radek Test Soukup (913)']
#
# MŠ Jihomoravské nám. 2 (46) ['Kamil Test Černý (2154)', 'Filip Test Macháček (986)', 'Matúš Test Procházka (1905)', 'Robin Test Dvořák (2253)', 'Róbert Test Toman (1826)', 'Martin Test Weiss (249)', 'Miloslava Test Procházková (4705)', 'Igor Test Vávra (1524)']
#
# MŠ Jugoslávská (47) ['Miroslav Test Kadlec (1430)', 'Anna Test Šťastná (2539)', 'Andrej Test Polák (1383)', 'Radek Test Černý (904)', 'Vladimír Test Urban (2112)', 'Karolína Test Marešová (2913)', 'Marek Test Svatoš (471)', 'Blanka Test Rýdlová (4130)']
#
# MŠ Zvídálek, Kachlíkova  (48) ['David Test Ronovský (446)', 'Róbert Test Janda (1834)', 'Miloslava Test Kočová (4738)', 'Peter Test Weiss (1349)', 'Stanislav Test Horváth (2032)', 'Viktor Test Šimek (1770)', 'Helena Test Tichá (2768)', 'Eva Test Smetanová (2690)']
#
# MŠ Skřivánek, Kachlíkova (49) ['Patricia Test Smetanová (3540)', 'Patricia Test Málková (3543)', 'Dominika Test Horáková (4208)', 'Lenka Test Matějová (3069)', 'Tomáš Test Navrátil (137)', 'Simona Test Procházková (3705)', 'Helena Test Tesařová (2787)', 'Gabriela Test Králová (4326)']
#
# MŠ Bieblova (5) ['Martin Test Smetana (240)', 'Barbora Test Horáková (2558)', 'Zdeňka Test Králová (3926)', 'Róbert Test Král (1816)', 'Vladislav Test Málek (2093)', 'Josef Test Staněk (2388)', 'Andrea Test Kučerová (4056)', 'Květoslava Test Pospíšilová (4662)']
#
# MŠ Duha, Kachlíkova (50) ['Jakub Test Vlček (578)', 'Soňa Test Horáková (3758)', 'Zuzana Test Jelínková (3970)', 'Vladislav Test Tomáš (2075)', 'Marie Test Rýdlová (4880)', 'Soňa Test Hájková (3772)', 'Erik Test Růžička (1867)', 'Marcela Test Novotná (3202)']
#
# MŠ Kamenáčky (51) ['Barbora Test Mrázková (2598)', 'Jozef Test Král (1166)', 'Irena Test Martínková (4392)', 'Václav Test Konečný (677)', 'Radim Test Kovařík (756)', 'Ondřej Test Pekař (639)', 'Viola Test Zábranská (4828)', 'Milan Test Marek (1061)']
#
# MŠ Kamenná (52) ['Karel Test Martínek (2442)', 'Gabriela Test Hajná (4347)', 'Alena Test Kopecká (4032)', 'Tereza Test Malá (3811)', 'Jaroslav Test Růžička (817)', 'Richard Test Vlček (1478)', 'Zuzana Test Marečková (3979)', 'Marta Test Černá (3254)']
#
# MŠ Kárníkova (53) ['Lenka Test Němcová (4459)', 'Soňa Test Tesařová (3787)', 'Štěpánka Test Tichá (4968)', 'Helena Test Benešová (2781)', 'Václav Test Urban (662)', 'Marcela Test Rýdlová (3230)', 'Anton Test Vávra (1274)', 'Karolína Test Horáková (2908)']
#
# MŠ Kavčí (54) ['Erik Test Konečný (1877)', 'Viola Test Benešová (4831)', 'Ludmila Test Procházková (3155)', 'Lucia Test Ronovská (3146)', 'Milan Test Vlček (1078)', 'Jakub Test Soukup (563)', 'Ludmila Test Hajná (3197)', 'Stanislava Test Ronovská (4546)']
#
# MŠ Klášterského (55) ['Klára Test Hlaváčková (3025)', 'Karolína Test Němcová (2909)', 'Anton Test Staněk (1288)', 'Miroslav Test Černý (1404)', 'Zuzana Test Zábranská (3978)', 'Renata Test Vlčková (3684)', 'Gabriela Test Jelínková (4320)', 'Lenka Test Šťastná (3089)']
#
# MŠ Kneslova (56) ['Josef Test Toman (2376)', 'Zdeňka Test Černá (3904)', 'Jaroslav Test Švadlenka (844)', 'Denisa Test Smetanová (2640)', 'David Test Pospíšil (410)', 'Filip Test Starý (991)', 'Kamila Test Hlaváčková (4425)', 'Jozef Test Procházka (1155)']
#
# MŠ Na osadě (58) ['Ivana Test Urbanová (2821)', 'Lukáš Test Dvořák (353)', 'Denisa Test Pospíšilová (2612)', 'Jozef Test Bílý (1169)', 'Marie Test Zábranská (4878)', 'Michaela Test Tesařová (3337)', 'Štěpán Test Vávra (2474)', 'Štěpán Test Ronovský (2496)']
#
# MŠ Kotlářská (59) ['Pavel Test Starý (341)', 'Ján Test Urban (1112)', 'Monika Test Smetanová (3390)', 'Róbert Test Vlček (1828)', 'Marie Test Novotná (4852)', 'Pavel Test Fiala (315)', 'Štěpán Test Janda (2484)', 'Kateřina Test Křenková (2983)']
#
# MŠ Bílého (6) ['Eva Test Ronovská (2696)', 'Ivan Test Němec (1209)', 'Ivan Test Dvořák (1203)', 'Juraj Test Černý (1654)', 'Josef Test Hajný (2397)', 'Štefan Test Pekař (1639)', 'Jiří Test Smetana (190)', 'Štěpán Test Soukup (2463)']
#
# MŠ Křenová (60) ['Denisa Test Tomášková (2635)', 'Filip Test Ronovský (996)', 'Jan Test Bílý (19)', 'Dominika Test Šťastná (4239)', 'Vladimír Test Hájek (2114)', 'Stanislava Test Kadlecová (4517)', 'Vladimír Test Horváth (2132)', 'Petr Test Weiss (99)']
#
# MŠ Křenová (61) ['Jakub Test Šimek (570)', 'Kamil Test Navrátil (2187)', 'Ivan Test Macháček (1236)', 'Monika Test Kočová (3388)', 'Pavlína Test Velínská (3595)', 'Josef Test Weiss (899)', 'Jan Test Toman (26)', 'Marie Test Kadlecová (4867)']
#
# MŠ Křídlovická (62) ['Vladislav Test Novotný (2052)', 'Patricia Test Havlíčková (3536)', 'Štefan Test Svoboda (1601)', 'Filip Test Pospíšil (960)', 'Filip Test Veselý (957)', 'Jakub Test Martínek (592)', 'Ivan Test Málek (1243)', 'Ján Test Weiss (1149)']
#
# MŠ Kšírova (63) ['Viktor Test Mrázek (1798)', 'Petra Test Švadlenková (3644)', 'Jakub Test Marek (561)', 'Klára Test Kučerová (3006)', 'Lenka Test Novotná (4452)', 'Anna Test Pospíšilová (2512)', 'Vladimír Test Němec (1559)', 'Anton Test Tomáš (1275)']
#
# MŠ Labská (64) ['Tomáš Test Novák (700)', 'Stanislav Test Konečný (2027)', 'Lucia Test Pospíšilová (3112)', 'Tomáš Test Dušek (735)', 'Květoslava Test Zábranská (4678)', 'Klára Test Konečná (3016)', 'Ivana Test Stará (2841)', 'Matúš Test Kratochvíl (1929)']
#
# MŠ Laštůvkova (65) ['Samuel Test Novák (1950)', 'Natálie Test Smetanová (3440)', 'Lenka Test Dvořáková (3053)', 'Josef Test Martínek (2392)', 'Ondřej Test Toman (626)', 'Jakub Test Růžička (567)', 'Lukáš Test Veselý (357)', 'Jaroslav Test Bílý (819)']
#
# MŠ Letní (66) ['Martin Test Kadlec (230)', 'Vladislav Test Mrázek (2098)', 'Barbora Test Šimková (2574)', 'Peter Test Růžička (1317)', 'Helena Test Křížová (2760)', 'Matúš Test Kadlec (1930)', 'Lenka Test Havlíčková (3086)', 'Zuzana Test Mrázková (3998)']
#
# MŠ Libušina třída (67) ['Jiří Test Marek (161)', 'Patrik Test Hájek (1714)', 'Juraj Test Novák (1650)', 'Petra Test Vondráčková (3627)', 'Marie Test Hájková (4872)', 'Dominika Test Procházková (4205)', 'Nikola Test Jelínková (3470)', 'Vladimíra Test Mrázková (4648)']
#
# MŠ Milénova (68) ['Adam Test Pekař (539)', 'Michaela Test Jelínková (3320)', 'Marie Test Pechová (4873)', 'Květoslava Test Hájková (4672)', 'Štěpánka Test Švadlenková (4994)', 'Eliška Test Šimková (4274)', 'Karel Test Němec (2409)', 'Juraj Test Horváth (1682)']
#
# MŠ Marie Majerové (69) ['Josef Test Pekař (2389)', 'Nikola Test Matějová (3469)', 'Martin Test Vlček (228)', 'Ludmila Test Hájková (3172)', 'Vladimír Test Navrátil (2137)', 'Daniela Test Procházková (4155)', 'Eva Test Veselá (2657)', 'Jana Test Velínská (2895)']
#
# MŠ Blanenská (7) ['Miloslava Test Křenková (4733)', 'Alena Test Tichá (4018)', 'Miroslav Test Kovařík (1406)', 'Adam Test Dušek (535)', 'Simona Test Rýdlová (3730)', 'Eliška Test Stará (4291)', 'Samuel Test Král (1966)', 'Martin Test Marek (211)']
#
# MŠ Family (70) ['Nikola Test Kadlecová (3467)', 'Nela Test Mrázková (4948)', 'Nikola Test Svobodová (3451)', 'Adam Test Kadlec (530)', 'Vladimíra Test Veselá (4607)', 'Karel Test Staněk (2438)', 'Vladimír Test Novotný (2102)', 'Marek Test Král (466)']
#
# MŠ Merhautova (71) ['David Test Toman (426)', 'Vladislav Test Mareš (2072)', 'Aleš Test Mrázek (1048)', 'Marcela Test Vondráčková (3227)', 'Zuzana Test Kučerová (3956)', 'Irena Test Matějová (4369)', 'Zuzana Test Horáková (3958)', 'Michal Test Vávra (274)']
#
# MŠ Měřičkova (72) ['Viola Test Malá (4811)', 'Radek Test Dvořák (903)', 'Veronika Test Novotná (3852)', 'Josef Test Kratochvíl (879)', 'Ondřej Test Beneš (618)', 'Alena Test Marešová (4013)', 'Andrea Test Veselá (4057)', 'Natálie Test Velínská (3445)']
#
# MŠ Radost (73) ['Eliška Test Křížová (4260)', 'Nela Test Velínská (4945)', 'Eva Test Konečná (2666)', 'Marcela Test Horáková (3208)', 'Viola Test Novotná (4802)', 'Ondřej Test Němec (609)', 'Natálie Test Havlíčková (3436)', 'Marie Test Horáková (4858)']
#
# MŠ Nádvorní (75) ['Josef Test Černý (2354)', 'Eva Test Horáková (2658)', 'Barbora Test Vlčková (2584)', 'Vladimír Test Hajný (1597)', 'Veronika Test Kopecká (3882)', 'Ivan Test Beneš (1218)', 'Štefan Test Černý (1604)', 'Dominika Test Pospíšilová (4212)']
#
# MŠ nám 28. října (76) ['Patricia Test Procházková (3505)', 'Lukáš Test Kratochvíl (379)', 'Juraj Test Mareš (1672)', 'Michaela Test Bílá (3315)', 'Tomáš Test Marek (111)', 'Ondřej Test Konečný (627)', 'Vladimír Test Novák (1550)', 'Richard Test Novotný (1452)']
#
# MŠ nám 28. října  / Stará (77) ['Martin Test Svoboda (201)', 'Marek Test Vávra (474)', 'Blanka Test Hlaváčková (4125)', 'Vladimír Test Tomáš (2125)', 'Matúš Test Bílý (1919)', 'Kamil Test Kovařík (2156)', 'Karel Test Macháček (2436)', 'Václav Test Pospíšil (660)']
#
# MŠ nám. Republiky (78) ['Lucia Test Havlíčková (3136)', 'Miroslav Test Soukup (1413)', 'Patricia Test Dvořáková (3503)', 'Patrik Test Veselý (1707)', 'Zuzana Test Stará (3991)', 'Štěpán Test Mareš (2472)', 'Anton Test Růžička (1267)', 'Štefan Test Fiala (1615)']
#
# MŠ nám. Svornosti (79) ['Pavel Test Svoboda (301)', 'Monika Test Svobodová (3351)', 'Vladislava Test Marešová (4563)', 'Samuel Test Kříž (1981)', 'Soňa Test Vlčková (3784)', 'Květoslava Test Němcová (4659)', 'Jozef Test Janda (1184)', 'Josef Test Navrátil (887)']
#
# MŠ Blažkova (8) ['Vladislava Test Kučerová (4556)', 'Ivana Test Málková (2843)', 'Samuel Test Navrátil (1987)', 'Jiří Test Weiss (199)', 'Matúš Test Růžička (1917)', 'Marie Test Mrázková (4898)', 'Pavlína Test Dvořáková (3553)', 'Ivan Test Veselý (1207)']
#
# MŠ nám. SNP (80) ['Dominika Test Zábranská (4228)', 'Renata Test Marešová (3663)', 'Adam Test Beneš (518)', 'Pavlína Test Svobodová (3551)', 'Adam Test Pospíšil (510)', 'Renata Test Matějová (3669)', 'Vladislava Test Zábranská (4578)', 'Václav Test Růžička (667)']
#
# MŠ Neklež (81) ['Václav Test Marek (661)', 'David Test Hájek (414)', 'Dominika Test Vondráčková (4227)', 'Nela Test Tomášková (4935)', 'Radim Test Procházka (755)', 'Dominika Test Matějová (4219)', 'Jozef Test Hájek (1164)', 'Michal Test Toman (276)']
#
# MŠ Nopova (82) ['Richard Test Švadlenka (1494)', 'Jan Test Vlček (28)', 'Jindřich Test Ronovský (2346)', 'Miloslav Test Konečný (2227)', 'Juraj Test Marek (1661)', 'Alena Test Kučerová (4006)', 'Štefan Test Konečný (1627)', 'Tomáš Test Pospíšil (710)']
#
# MŠ Novoměstská (83) ['Vladimíra Test Velínská (4645)', 'Marek Test Kadlec (480)', 'Helena Test Jelínková (2770)', 'Erik Test Černý (1854)', 'Robin Test Janda (2284)', 'Lukáš Test Konečný (377)', 'Erik Test Dušek (1885)', 'Vladimír Test Svoboda (1551)']
#
# MŠ Pomněnky (84) ['Viola Test Málková (4843)', 'Josef Test Fiala (865)', 'Klára Test Zábranská (3028)', 'Marta Test Mrázková (3298)', 'Marek Test Urban (462)', 'Viktor Test Marek (1761)', 'Pavel Test Růžička (317)', 'Alena Test Zábranská (4028)']
#
# MŠ Oderská (85) ['Anna Test Stará (2541)', 'Matúš Test Novotný (1902)', 'Petra Test Růžičková (3614)', 'Róbert Test Beneš (1818)', 'Ján Test Marek (1111)', 'Eliška Test Hajná (4297)', 'Robin Test Toman (2276)', 'Kateřina Test Dvořáková (2953)']
#
# MŠ Ondrova (86) ['Anna Test Rýdlová (2530)', 'Vladimír Test Pospíšil (2110)', 'Jaroslav Test Kratochvíl (829)', 'Róbert Test Dušek (1835)', 'Aleš Test Konečný (1027)', 'Jaroslav Test Marek (811)', 'Michal Test Novák (250)', 'Radim Test Navrátil (787)']
#
# MŠ Pastviny (87) ['Filip Test Polák (983)', 'Hana Test Černá (2704)', 'Kamil Test Veselý (2157)', 'David Test Marek (411)', 'Kamil Test Svatoš (2171)', 'Jindřich Test Král (2316)', 'Ivana Test Kadlecová (2817)', 'Michal Test Černý (254)']
#
# MŠ Zdislava (88) ['Pavel Test Mach (323)', 'Richard Test Mareš (1472)', 'Veronika Test Šimková (3874)', 'Petr Test Svoboda (51)', 'Peter Test Horák (1308)', 'Marie Test Tichá (4868)', 'Tereza Test Svobodová (3801)', 'Vladislava Test Tomášková (4585)']
#
# MŠ Sněhurka (9) ['Gabriela Test Kopecká (4332)', 'Vladislava Test Kopecká (4582)', 'Kateřina Test Jelínková (2970)', 'Pavel Test Mareček (345)', 'Renata Test Martínková (3692)', 'Erik Test Macháček (1886)', 'Lenka Test Urbanová (4471)', 'Lucia Test Kučerová (3106)']
#
# MŠ Beruška (90) ['Josef Test Dvořák (2353)', 'Renata Test Hlaváčková (3675)', 'Natálie Test Martínková (3442)', 'David Test Horák (408)', 'Martin Test Němec (209)', 'Monika Test Křenková (3383)', 'Andrej Test Macháček (1386)', 'Blanka Test Svobodová (4101)']
#
# MŠ Proškovo nám. (91) ['Zdeňka Test Švadlenková (3944)', 'Pavel Test Vlček (328)', 'Josef Test Král (866)', 'Karel Test Tomáš (2425)', 'Veronika Test Hájková (3872)', 'Hana Test Němcová (2709)', 'Lenka Test Horáková (4458)', 'Zdeňka Test Tomášková (3935)']
#
# MŠ Prušánecká (92) ['Daniela Test Havlíčková (4186)', 'Radek Test Smetana (940)', 'Zdeňka Test Tesařová (3937)', 'Marta Test Křenková (3283)', 'Kamil Test Pospíšil (2160)', 'Helena Test Pospíšilová (2762)', 'Štěpánka Test Mrázková (4998)', 'Petr Test Veselý (57)']
#
# MŠ Přemyslovo nám. (93) ['Vladimíra Test Stará (4641)', 'Blanka Test Weissová (4149)', 'Jozef Test Horváth (1182)', 'Jaroslav Test Černý (804)', 'Ondřej Test Navrátil (637)', 'Michaela Test Hlaváčková (3325)', 'Marek Test Veselý (457)', 'Václav Test Kříž (681)']
#
# MŠ Pšeník (94) ['Marcela Test Dvořáková (3203)', 'Miloslava Test Marešová (4713)', 'Ivana Test Kočová (2838)', 'Marek Test Konečný (477)', 'Jan Test Pekař (39)', 'Štefan Test Němec (1609)', 'Vladimír Test Smetana (2140)', 'Štěpán Test Pekař (2489)']
#
# MŠ Puchýřova (95) ['Milada Test Mrázková (4798)', 'Renata Test Bílá (3665)', 'Robin Test Soukup (2263)', 'Karolína Test Weissová (2949)', 'Vladimíra Test Křenková (4633)', 'Květoslava Test Vondráčková (4677)', 'Stanislav Test Smetana (2040)', 'Petra Test Nováková (3600)']
#
# MŠ Purkyňova (96) ['Josef Test Hájek (864)', 'David Test Konečný (427)', 'Ludmila Test Růžičková (3164)', 'Ivan Test Ronovský (1246)', 'Kamil Test Málek (2193)', 'Filip Test Kadlec (980)', 'Alena Test Křížová (4010)', 'Ondřej Test Janda (634)']
#
# MŠ Vážka (97) ['Marta Test Šťastná (3289)', 'Marek Test Kratochvíl (479)', 'Viola Test Smetanová (4840)', 'Hana Test Vondráčková (2727)', 'Jindřich Test Šimek (2320)', 'Zuzana Test Konečná (3966)', 'Dominika Test Kopecká (4232)', 'Róbert Test Svoboda (1801)']
#
# MŠ Řezáčova (98) ['Blanka Test Růžičková (4114)', 'Ivana Test Malá (2811)', 'Lukáš Test Procházka (355)', 'Milada Test Jelínková (4770)', 'Nela Test Weissová (4949)', 'Miloslava Test Černá (4704)', 'Karolína Test Matějová (2919)', 'Matúš Test Janda (1934)']
#
# MŠ Síčka (99) ['Soňa Test Vondráčková (3777)', 'Josef Test Svatoš (2371)', 'Vladislav Test Mach (2073)', 'Adam Test Ronovský (546)', 'Tereza Test Tichá (3818)', 'Stanislav Test Marek (2011)', 'Aleš Test Růžička (1017)', 'Veronika Test Málková (3893)']
#
#
#
# Neúspěšní uchazeči:
#
# Michal Test Dušek (285)
# Kamila Test Hajná (4447)
# Anna Test Procházková (2505)
# Josef Test Král (2366)
# Ondřej Test Mach (623)
# Karel Test Marek (2411)
# Vladislava Test Hajná (4597)
